# %%
# WeatherPy
----

### Analysis
* As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
* There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
* There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

---

#### Note
* Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
# Out:
#   File "<ipython-input-1-8af967f69e63>", line 2
#     ----
#         ^
# SyntaxError: invalid syntax

# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
temp=[]
lat=[]
lng=[]
wind=[]

# %%
record_counter=0
set_counter=0
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print('--------------------------')
print('Beginning Data Retrieval')
print('--------------------------')

for city in cities:
    query_url=url + "&q=" + city
    #Get weather data
    response=requests.get(query_url).json()
    if  record_counter<50:
        record_counter +=1  
    else:
        set_counter +=1
        record_counter=0
        
    print('Processing record {} of set {}|{}'.format(record_counter,set_counter, city))
    print(url)
    
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response ['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['coord']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
        
    except:
        print("City not found!")
        pass
        
print('-------------------')
print('Data Retrieval Complete')
print('-------------------')
# Out:
# --------------------------
# Beginning Data Retrieval
# --------------------------
# Processing record 1 of set 0|bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 2 of set 0|anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 3 of set 0|taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 4 of set 0|barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 5 of set 0|port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 6 of set 0|bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 7 of set 0|butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 8 of set 0|marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 9 of set 0|castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 10 of set 0|bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 11 of set 0|cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 12 of set 0|mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 13 of set 0|balykshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 14 of set 0|sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 15 of set 0|avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 16 of set 0|bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 17 of set 0|ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 18 of set 0|staryy nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 19 of set 0|saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 20 of set 0|busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 21 of set 0|alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 22 of set 0|paucartambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 23 of set 0|kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 24 of set 0|hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 25 of set 0|carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 26 of set 0|danville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 27 of set 0|barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 28 of set 0|vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 29 of set 0|chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 30 of set 0|ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 31 of set 0|caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 32 of set 0|sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 33 of set 0|georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 34 of set 0|faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 35 of set 0|ziro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 36 of set 0|jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 37 of set 0|vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 38 of set 0|tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 39 of set 0|bonanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 40 of set 0|punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 41 of set 0|hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 42 of set 0|arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 43 of set 0|ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 44 of set 0|staffanstorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 45 of set 0|albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 46 of set 0|gweta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 47 of set 0|vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 48 of set 0|rudnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 49 of set 0|ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 50 of set 0|one hundred mile house
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 0 of set 1|provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 1 of set 1|shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 2 of set 1|leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 3 of set 1|caxito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 4 of set 1|yasnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 5 of set 1|puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 6 of set 1|faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 7 of set 1|yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 8 of set 1|bembereke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 9 of set 1|longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 10 of set 1|dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 11 of set 1|tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 12 of set 1|krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 13 of set 1|nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 14 of set 1|ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 15 of set 1|babanusah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 16 of set 1|karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 17 of set 1|cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 18 of set 1|miles city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 19 of set 1|tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 20 of set 1|udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 21 of set 1|kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 22 of set 1|kalmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 23 of set 1|sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 24 of set 1|chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 25 of set 1|rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 26 of set 1|lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 27 of set 1|coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 28 of set 1|wad madani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 29 of set 1|zabaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 30 of set 1|kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 31 of set 1|tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 32 of set 1|necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 33 of set 1|alamosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 34 of set 1|saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 35 of set 1|adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 36 of set 1|delta del tigre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 37 of set 1|pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 38 of set 1|east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 39 of set 1|samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record

# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 28 of set 10|nampa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 29 of set 10|iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 30 of set 10|mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 31 of set 10|aldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 32 of set 10|shaoguan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 33 of set 10|dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 34 of set 10|saravena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 35 of set 10|mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 36 of set 10|puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 37 of set 10|roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 38 of set 10|komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 39 of set 10|margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 40 of set 10|kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 41 of set 10|natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 42 of set 10|hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 43 of set 10|bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 44 of set 10|gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 45 of set 10|kimry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 46 of set 10|prado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 47 of set 10|walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 48 of set 10|atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 49 of set 10|srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 50 of set 10|kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 0 of set 11|damaturu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 1 of set 11|namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 2 of set 11|kenitra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 3 of set 11|kyra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 4 of set 11|jacqueville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 5 of set 11|baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 6 of set 11|jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 7 of set 11|florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 8 of set 11|huangchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 9 of set 11|garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 10 of set 11|pinar del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 11 of set 11|semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 12 of set 11|kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 13 of set 11|neverkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 14 of set 11|makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 15 of set 11|winneba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 16 of set 11|nobeoka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 17 of set 11|port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 18 of set 11|bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 19 of set 11|westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 20 of set 11|qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 21 of set 11|berbera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 22 of set 11|sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 23 of set 11|yudong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 24 of set 11|coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 25 of set 11|popesti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 26 of set 11|newton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 27 of set 11|chazuta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 28 of set 11|japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 29 of set 11|abapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 30 of set 11|pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 31 of set 11|verkhniy uslon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 32 of set 11|karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 33 of set 11|luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 34 of set 11|grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 35 of set 11|misratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 36 of set 11|celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 37 of set 11|elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 38 of set 11|shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 39 of set 11|champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 40 of set 11|neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 41 of set 11|kabrai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 42 of set 11|krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# Processing record 43 of set 11|bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a822a39a38d26134542b7abf3ac5087
# City not found!
# -------------------
# Data Retrieval Complete
# -------------------

# %%
Convert Raw Data to DataFrame
.Export the city data into a .csv.
.Display the DataFrame

# %%
#create a data framefrom cities, temp, humidity,cloudiness and wind speed
weather_dict={"City":new_cities, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,
              "Temp":temp,"Lat": lat,"Lng": lng, "Wind Speed": wind ,}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3fca7dfe06b1> in <module>
#       2 weather_dict={"City":new_cities, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,
#       3               "Temp":temp,"Lat": lat,"Lng": lng, "Wind Speed": wind ,}
# ----> 4 weather_data = pd.DataFrame(weather_dict)
#       5 weather_data.count()
#
# ~\Anaconda3\envs\pythonData2\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\envs\pythonData2\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~\Anaconda3\envs\pythonData2\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~\Anaconda3\envs\pythonData2\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
weather_data.to_csv('weather.csv', index=False, header=None)

weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8d757a6e37d5> in <module>
# ----> 1 weather_data.to_csv('weather.csv', index=False, header=None)
#       2
#       3 weather_data.head()
#
# NameError: name 'weather_data' is not defined

# %%
date = datetime.date.today()
date
datetime.date(2019, 2, 27)
# Out:
# datetime.date(2019, 2, 27)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data.plot(kind ='scatter', x ='Lat', y ='Temp', c ='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c9ff7b573538> in <module>
# ----> 1 weather_data.plot(kind ='scatter', x ='Lat', y ='Temp', c ='DarkBlue')
#       2 plt.title('City Latitude Vs Max Temperature ({})'.format(date))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Max Temperature (F)')
#       5 plt.grid()
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Max Humidity (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ddfc6056a151> in <module>
# ----> 1 weather_data.plot(kind='scatter', x='Lat', y='Humidity', c='DarkBlue')
#       2 plt.title('City Latitude Vs Max Humidity ({})'.format(date))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Max Humidity (F)')
#       5 plt.grid()
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Max Cloudiness ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Max Cloudiness (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-27dad7bea6b4> in <module>
# ----> 1 weather_data.plot(kind='scatter', x='Lat', y='Cloudiness', c='DarkBlue')
#       2 plt.title('City Latitude Vs Max Cloudiness ({})'.format(date))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Max Cloudiness (F)')
#       5 plt.grid()
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Max Wind Speed ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Max Wind Speed (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsWind Speed.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d2779e62383f> in <module>
# ----> 1 weather_data.plot(kind='scatter', x='Lat', y='Wind Speed', c='DarkBlue')
#       2 plt.title('City Latitude Vs Max Wind Speed ({})'.format(date))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Max Wind Speed (F)')
#       5 plt.grid()
#
# NameError: name 'weather_data' is not defined
